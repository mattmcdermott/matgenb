# %% [markdown]
# # Introduction
#
# This notebook demonstrates how to predict structures using the built-in *structure_prediction* package in pymatgen. We will be gathering all possible structures (via the Materials API) of the chemical systems containing the highest probability specie substitutions for our original species. We will then resubstitute the original species back into these structures, filter out duplicates as well as preexisting structures already on the Materials Project, and output the newly predicted structures.
#
#
# Written using:
# - pymatgen==2018.9.19
#
# *Author: Matthew McDermott (09/25/18)*

# %%
# Imports we need for running structure prediction

from pymatgen.analysis.structure_prediction.substitutor import Substitutor 
from pymatgen.analysis.structure_prediction.substitution_probability import SubstitutionPredictor
from pymatgen.analysis.structure_matcher import StructureMatcher, ElementComparator
from pymatgen.transformations.standard_transformations import AutoOxiStateDecorationTransformation
from pymatgen import Specie, Element
from pymatgen import MPRester
from pprint import pprint

# %%
# Establish rester for accessing Materials API
mpr = MPRester(api_key='########') # INSERT YOUR OWN API KEY

# %% [markdown]
# Here we define two variables -- *threshold* for the threshold probability in making substitution/structure predictions, and *num_subs* for how many substitutions you wish to explore:

# %%
threshold = 0.001 #threshold for substitution/structure predictions
num_subs = 10 # number of highest probability substitutions you wish to see

# %% [markdown]
# # Finding highest probability specie substitutions
#
# In this section, we use the SubstitutionPredictor to predict likely specie substitutions using a data-mined approach from ICSD data. This does not yet calculate probable structures -- only which species are likely to substitute for the original species you input. The substitution prediction methodology is presented in:
# *Hautier, G., Fischer, C., Ehrlacher, V., Jain, A., and Ceder, G. (2011) Data Mined Ionic Substitutions for the Discovery of New Compounds. Inorganic Chemistry, 50(2), 656-663. doi:10.1021/ic102031h*

# %%
original_species = [Specie('Y',3), Specie('Mn',3), Specie('O',-2)] # List of original species for substituting into

# %% [markdown]
# Predict most common specie substitutions, sort by highest probability, and take the number of substitutions specified by *num_subs*:

# %%
subs = SubstitutionPredictor(threshold=threshold).list_prediction(original_species)
subs.sort(key = lambda x: x['probability'], reverse = True)
subs = subs[0:num_subs]
pprint(subs)
# Out:
# [{'probability': 0.013371287006021228,
#   'substitutions': {Specie Y3+: Specie Y3+,
#                     Specie Mn3+: Specie Mn3+,
#                     Specie O2-: Specie O2-}},
#  {'probability': 0.006955965572918694,
#   'substitutions': {Specie Na+: Specie Y3+,
#                     Specie Mn3+: Specie Mn3+,
#                     Specie O2-: Specie O2-}},
#  {'probability': 0.00531546048721354,
#   'substitutions': {Specie Mn3+: Specie Mn3+,
#                     Specie Re5+: Specie Y3+,
#                     Specie O2-: Specie O2-}},
#  {'probability': 0.004872512156006503,
#   'substitutions': {Specie Y3+: Specie Y3+,
#                     Specie Fe3+: Specie Mn3+,
#                     Specie O2-: Specie O2-}},
#  {'probability': 0.004742382503118587,
#   'substitutions': {Specie Y3+: Specie Y3+,
#                     Specie Sc3+: Specie Mn3+,
#                     Specie O2-: Specie O2-}},
#  {'probability': 0.004621732557387755,
#   'substitutions': {Specie Yb3+: Specie Y3+,
#                     Specie Mn3+: Specie Mn3+,
#                     Specie O2-: Specie O2-}},
#  {'probability': 0.004484870617262708,
#   'substitutions': {Specie K+: Specie Y3+,
#                     Specie Mn3+: Specie Mn3+,
#                     Specie O2-: Specie O2-}},
#  {'probability': 0.004395976308587982,
#   'substitutions': {Specie Ho3+: Specie Y3+,
#                     Specie Mn3+: Specie Mn3+,
#                     Specie O2-: Specie O2-}},
#  {'probability': 0.0042937893748432945,
#   'substitutions': {Specie Nd3+: Specie Y3+,
#                     Specie Mn3+: Specie Mn3+,
#                     Specie O2-: Specie O2-}},
#  {'probability': 0.004225888976078506,
#   'substitutions': {Specie Er3+: Specie Y3+,
#                     Specie Mn3+: Specie Mn3+,
#                     Specie O2-: Specie O2-}}]

# %% [markdown]
# Create a new list of just the substituted specie combinations:

# %%
trial_subs = [list(sub['substitutions'].keys()) for sub in subs]
pprint(trial_subs)
# Out:
# [[Specie Y3+, Specie Mn3+, Specie O2-],
#  [Specie Na+, Specie Mn3+, Specie O2-],
#  [Specie Re5+, Specie Mn3+, Specie O2-],
#  [Specie Y3+, Specie Fe3+, Specie O2-],
#  [Specie Y3+, Specie Sc3+, Specie O2-],
#  [Specie Yb3+, Specie Mn3+, Specie O2-],
#  [Specie K+, Specie Mn3+, Specie O2-],
#  [Specie Ho3+, Specie Mn3+, Specie O2-],
#  [Specie Nd3+, Specie Mn3+, Specie O2-],
#  [Specie Er3+, Specie Mn3+, Specie O2-]]

# %% [markdown]
# Create a set of strings of each unique chemical system (elements separated by dashes):

# %%
elem_sys_list = [[specie.element for specie in sub] for sub in trial_subs]

chemsys_set = set()
for sys in elem_sys_list:
    chemsys_set.add("-".join(map(str,sys)))
    
pprint(chemsys_set)
# Out:
# {'Er-Mn-O',
#  'Ho-Mn-O',
#  'K-Mn-O',
#  'Na-Mn-O',
#  'Nd-Mn-O',
#  'Re-Mn-O',
#  'Y-Fe-O',
#  'Y-Mn-O',
#  'Y-Sc-O',
#  'Yb-Mn-O'}

# %% [markdown]
# # Finding all structures for new chemical systems via Materials API
#
# Create a new dictionary and populate it with all structures for each chemical system:

# %%
all_structs = {}
for chemsys in chemsys_set:
    all_structs[chemsys] = mpr.get_structures(chemsys) # Getting all structures -- this can take a while!

# %%
auto_oxi = AutoOxiStateDecorationTransformation() # create object to determine oxidation states at each lattice site

# %% [markdown]
# Now create a new dictionary of all structures (with oxidation states) for each chemical system:

# %%
oxi_structs = {}

for chemsys in all_structs:
    oxi_structs[chemsys] = []
    
    for num, struct in enumerate(all_structs[chemsys]):
        try:
            oxi_structs[chemsys].append({'structure': auto_oxi.apply_transformation(struct), 
                                         'id': str(chemsys + "_" + str(num))})
        except:
            continue # if auto oxidation fails, try next structure
            
#pprint(oxi_structs)

# %% [markdown]
# # Substitute original species into new structures
#
# Now create a new dictionary *trans_structures* populated with predicted structures made up of original species. Note: these new predicted structures are *TransformedStructure* objeects:

# %%
sbr = Substitutor(threshold = threshold) # create a Substitutor object with structure prediction threshold

# %%
trans_structs = {}

for chemsys in oxi_structs:
    trans_structs[chemsys] = sbr.pred_from_structures(original_species,oxi_structs[chemsys])

# %% [markdown]
# Filter duplicate structures using StructureMatcher:

# %%
sm = StructureMatcher(comparator=ElementComparator(),primitive_cell=False) # create object for structure matching

# %%
filtered_structs = {} # new filtered dictionary
seen_structs = [] # list of all seen structures, independent of chemical system

print("Number of entries BEFORE filtering: " + str(sum([len(sys) for sys in trans_structs.values()])))

for chemsys in trans_structs:
    filtered_structs[chemsys] = []
    for struct in trans_structs[chemsys]:
        found = False
        for struct2 in seen_structs:
            if sm.fit(struct.final_structure, struct2.final_structure):
                found = True
                break
        if not found:
            filtered_structs[chemsys].append(struct)
            seen_structs.append(struct)
            
print("Number of entries AFTER filtering: " + str(sum([len(sys) for sys in filtered_structs.values()])))
# Out:
# Number of entries BEFORE filtering: 16
# Number of entries AFTER filtering: 6

# %% [markdown]
# *NOTE: The chemical systems to which the filtered structures are assigned might change when re-running the program. Since we are filtering for duplicates across chemical systems, either of the two systems may be reported in the filtered dictionary. Which of the two systems it is simply depends on the order in that the filter algorithm follows (and it's reading from a naturally unordered dictionary!)*

# %% [markdown]
# Now we wish to run one more filter to remove all duplicate structures already accessible on the Materials Project.

# %%
known_structs = mpr.get_structures("Y-Mn-O") # get all known MP structures for original system

# %%
final_filtered_structs = {}
print("Number of entries BEFORE filtering against MP: " + str(sum([len(sys) for sys in filtered_structs.values()])))

for chemsys in filtered_structs:
    final_filtered_structs[chemsys] = []
    for struct in filtered_structs[chemsys]:
        found = False
        for struct2 in known_structs:
            if sm.fit(struct.final_structure, struct2):
                found = True
                break 
        if not found:
            final_filtered_structs[chemsys].append(struct)
                
print("Number of entries AFTER filtering against MP: " + str(sum([len(sys) for sys in final_filtered_structs.values()])))
pprint(final_filtered_structs)
# Out:
# Number of entries BEFORE filtering against MP: 6
# Number of entries AFTER filtering against MP: 1
# {'Er-Mn-O': [],
#  'Ho-Mn-O': [],
#  'K-Mn-O': [],
#  'Na-Mn-O': [],
#  'Nd-Mn-O': [],
#  'Re-Mn-O': [],
#  'Y-Fe-O': [<pymatgen.alchemy.materials.TransformedStructure object at 0x1262dbc88>],
#  'Y-Mn-O': [],
#  'Y-Sc-O': [],
#  'Yb-Mn-O': []}

# %% [markdown]
# Create final structure dictionary with StructureNL objects for each transformed structure (*Note: this requires installation of pybtex*):

# %%
final_structs = {}
for chemsys in final_filtered_structs:
    final_structs[chemsys] = [struct.to_snl([{"name":"Matthew McDermott", "email":"N/A"}]) 
                              for struct in final_filtered_structs[chemsys]]

pprint(final_structs['Y-Fe-O'][0].as_dict()) # Printing one of the StructureNL objects - this is a large dictionary!
# Out:
# {'@class': 'StructureNL',
#  '@module': 'pymatgen.util.provenance',
#  'about': {'authors': [{'email': 'N/A', 'name': 'Matthew McDermott'}],
#            'created_at': {'@class': 'datetime',
#                           '@module': 'datetime',
#                           'string': '2018-09-26 00:23:45.806165'},
#            'history': [{'description': {'source': 'Y-Fe-O_13'},
#                         'name': 'pymatgen',
#                         'url': 'http://pypi.python.org/pypi/pymatgen'},
#                        {'description': {'@class': 'SubstitutionTransformation',
#                                         '@module': 'pymatgen.transformations.standard_transformations',
#                                         'input_structure': {'@class': 'Structure',
#                                                             '@module': 'pymatgen.core.structure',
#                                                             'charge': None,
#                                                             'lattice': {'a': 10.877090414496907,
#                                                                         'alpha': 109.47008972021582,
#                                                                         'b': 10.877090085462694,
#                                                                         'beta': 109.47008910095691,
#                                                                         'c': 10.87708998587291,
#                                                                         'gamma': 109.47008495897774,
#                                                                         'matrix': [[10.25523798,
#                                                                                     -0.00076495,
#                                                                                     -3.62507783],
#                                                                                    [-5.12608431,
#                                                                                     8.88218213,
#                                                                                     -3.62507779],
#                                                                                    [-0.00044177,
#                                                                                     -0.000765,
#                                                                                     10.87708995]],
#                                                                         'volume': 990.6825344900772},
#                                                             'sites': [{'abc': [0.24992786,
#                                                                                0.37496267,
#                                                                                0.12492739],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [0.6409242334363346,
#                                                                                3.3301999751212303,
#                                                                                -0.9064303332327126]},
#                                                                       {'abc': [0.6250483,
#                                                                                0.25002519,
#                                                                                0.8750024],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [5.127982312120417,
#                                                                                2.21962176713477,
#                                                                                6.34527031304716]},
#                                                                       {'abc': [0.75007214,
#                                                                                0.62503733,
#                                                                                0.87507261],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [4.487787666563666,
#                                                                                5.55045220487877,
#                                                                                4.533364663232714]},
#                                                                       {'abc': [0.74997481,
#                                                                                0.1249976,
#                                                                                0.3749517],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [7.0502562769951185,
#                                                                                1.1093909177314787,
#                                                                                0.9065402874526489]},
#                                                                       {'abc': [0.87507261,
#                                                                                0.75007214,
#                                                                                0.62503733],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [5.12886871436633,
#                                                                                6.66112981776839,
#                                                                                0.9073110867548264]},
#                                                                       {'abc': [0.25002519,
#                                                                                0.8750024,
#                                                                                0.6250483],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [-1.9215443769951184,
#                                                                                7.7712612622685215,
#                                                                                2.720394042547351]},
#                                                                       {'abc': [0.62503733,
#                                                                                0.87507261,
#                                                                                0.75007214],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [1.9238792299327563,
#                                                                                7.771502371501776,
#                                                                                2.720586884715267]},
#                                                                       {'abc': [0.1249976,
#                                                                                0.3749517,
#                                                                                0.74997481],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [-0.6404852078207928,
#                                                                                3.3297199417093513,
#                                                                                6.345188360048209]},
#                                                                       {'abc': [0.3749517,
#                                                                                0.74997481,
#                                                                                0.1249976],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [0.0007295878795824527,
#                                                                                6.66103041286523,
#                                                                                -2.7183359830471607]},
#                                                                       {'abc': [0.37496267,
#                                                                                0.12492739,
#                                                                                0.24992786],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [3.204832670067243,
#                                                                                1.109149808498224,
#                                                                                0.9063474452847329]},
#                                                                       {'abc': [0.8750024,
#                                                                                0.6250483,
#                                                                                0.25002519],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [5.769197107820793,
#                                                                                5.550932238290649,
#                                                                                -2.7182540300482083]},
#                                                                       {'abc': [0.12492739,
#                                                                                0.24992786,
#                                                                                0.37496267],
#                                                                        'label': 'Y3+',
#                                                                        'properties': {'magmom': 0.027},
#                                                                        'species': [{'element': 'Y',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [-0.00015681436633039502,
#                                                                                2.2195223622316114,
#                                                                                2.7196232432451737]},
#                                                                       {'abc': [0.87500177,
#                                                                                0.25003546,
#                                                                                0.12502881],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [7.6915933018441995,
#                                                                                2.2200955150347186,
#                                                                                -2.7183978976847323]},
#                                                                       {'abc': [0.25023634,
#                                                                                0.62517503,
#                                                                                0.37507791],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [-0.6386323925108865,
#                                                                                5.55244012669878,
#                                                                                0.9063218408180784]},
#                                                                       {'abc': [0.0,
#                                                                                0.5,
#                                                                                0.5],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.404},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [-2.5632630400000003,
#                                                                                4.440708565,
#                                                                                3.62600608]},
#                                                                       {'abc': [0.25003546,
#                                                                                0.12502881,
#                                                                                0.87500177],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [1.9228783749678666,
#                                                                                1.1096680209379883,
#                                                                                8.157835793698231]},
#                                                                       {'abc': [0.5,
#                                                                                0.0,
#                                                                                0.0],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.404},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [5.12761899,
#                                                                                -0.000382475,
#                                                                                -1.812538915]},
#                                                                       {'abc': [0.62517503,
#                                                                                0.37507791,
#                                                                                0.25023634],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [4.488527175417126,
#                                                                                3.3308406511204502,
#                                                                                -0.9041515632444206]},
#                                                                       {'abc': [0.5,
#                                                                                0.0,
#                                                                                0.5],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.404},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [5.127398105,
#                                                                                -0.000764975,
#                                                                                3.62600606]},
#                                                                       {'abc': [0.37482497,
#                                                                                0.62492209,
#                                                                                0.74976366],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [0.6401847245828742,
#                                                                                5.549811528879551,
#                                                                                4.5310858932444225]},
#                                                                       {'abc': [0.62492209,
#                                                                                0.74976366,
#                                                                                0.37482497],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [2.565207431747806,
#                                                                                6.658772607320601,
#                                                                                -0.9063378913553253]},
#                                                                       {'abc': [0.87497119,
#                                                                                0.12499823,
#                                                                                0.74996454],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [8.331955001678189,
#                                                                                1.1090140127027395,
#                                                                                4.532464790770344]},
#                                                                       {'abc': [0.0,
#                                                                                0.5,
#                                                                                0.0],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.404},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [-2.563042155,
#                                                                                4.441091065,
#                                                                                -1.812538895]},
#                                                                       {'abc': [0.12502881,
#                                                                                0.87500177,
#                                                                                0.25003546],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [-3.20324310167819,
#                                                                                7.771638167297262,
#                                                                                -0.9055304607703438]},
#                                                                       {'abc': [0.0,
#                                                                                0.0,
#                                                                                0.0],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.404},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [0.0,
#                                                                                0.0,
#                                                                                0.0]},
#                                                                       {'abc': [0.74996454,
#                                                                                0.87497119,
#                                                                                0.12499823],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [3.205833525032133,
#                                                                                7.770984159062013,
#                                                                                -4.53090146369823]},
#                                                                       {'abc': [0.37507791,
#                                                                                0.25023634,
#                                                                                0.62517503],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [2.5635044682521935,
#                                                                                2.2218795726794,
#                                                                                4.5332722213553245]},
#                                                                       {'abc': [0.0,
#                                                                                0.0,
#                                                                                0.5],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.404},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [-0.000220885,
#                                                                                -0.0003825,
#                                                                                5.438544975]},
#                                                                       {'abc': [0.12499823,
#                                                                                0.74996454,
#                                                                                0.87497119],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [-2.5628814018441988,
#                                                                                6.6605566649652825,
#                                                                                6.345332227684734]},
#                                                                       {'abc': [0.74976366,
#                                                                                0.37482497,
#                                                                                0.62492209],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.276},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [5.767344292510888,
#                                                                                3.3282120533012187,
#                                                                                2.7206124891819217]},
#                                                                       {'abc': [0.5,
#                                                                                0.5,
#                                                                                0.5],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.404},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [2.56435595,
#                                                                                4.44032609,
#                                                                                1.813467165]},
#                                                                       {'abc': [0.5,
#                                                                                0.5,
#                                                                                0.0],
#                                                                        'label': 'Fe3+',
#                                                                        'properties': {'magmom': 4.404},
#                                                                        'species': [{'element': 'Fe',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': 3}],
#                                                                        'xyz': [2.564576835,
#                                                                                4.44070859,
#                                                                                -3.62507781]},
#                                                                       {'abc': [0.6250667,
#                                                                                0.41692244,
#                                                                                0.09409026],
#                                                                        'label': 'O2-',
#                                                                        'properties': {'magmom': 0.216},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
#                                                                        'xyz': [4.272986617448189,
#                                                                                3.7026309223429323,
#                                                                                -2.753863492398982]},
#                                                                       {'abc': [0.4685611,
#                                                                                0.59368791,
#                                                                                0.17689958],
#                                                                        'label': 'O2-',
#                                                                        'properties': {'magmom': 0.216},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
#                                                                        'xyz': [1.7618331592554293,
#                                                                                5.272750391006903,
#                                                                                -1.9265826685657113]},
#                                                                       {'abc': [0.90618457,
#                                                                                0.03123282,
#                                                                                0.32291068],
#                                                                        'label': 'O2-',
#                                                                        'properties': {'magmom': 0.216},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
#                                                                        'xyz': [9.132893698343812,
#                                                                                0.2764753831164851,
#                                                                                0.11411751547951532]},
#                                                                       {'abc': [0.59368791,
#                                                                                0.17689958,
#                                                                                0.4685611],
#                                                                        'label': 'O2-',
#                                                                        'properties': {'magmom': 0.216},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
#                                                                        'xyz': [5.181401645178084,
#                                                                                1.5704416974722508,
#                                                                                2.3031416127725817]},
#                                                                       {'abc': [0.53106465,
#                                                                                0.62522516,
#                                                                                0.70812995],
#                                                                        'label': 'O2-',
#                                                                        'properties': {'magmom': 0.216},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
#                                                                        'xyz': [2.240924655054157,
#                                                                                5.552415786062624,
#                                                                                3.510752632162097]},
#                                                                       {'abc': [0.08322579,
#                                                                                0.87491292,
#                                                                                0.40617864],
#                                                                        'label': 'O2-',
#                                                                        'properties': {'magmom': 0.216},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
#                                                                        'xyz': [-3.631556546842574,
#                                                                                7.770761513102459,
#                                                                                0.9447142423593848]},
#                                                                       {'abc': [0.96891421,
#                                                                                0.79181178,
#                                                                                0.87482955],
#                                                                        'label': 'O2-',
#                                                                        'properties': {'magmom': 0.216},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
#                                                                        'xyz': [5.8771653903722205,
#                                                                                7.0316060271088014,
#                                                                                3.1328309868866917]},
#                                                                       {'abc': [0.91677421,
#                                                                                0.12508708,
#                                                                                0.59382136],
#                                                                        'label': 'O2-',
#                                                                        'properties': {'magmom': 0.216},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
#                                                                        'xyz': [8.760268446842575,
#                                                                                1.1098906668975408,
#                                                                                2.682220087640614]},
#                                                                       {'abc': [0.58307756,
#                                                                                0.90590974,
#                                                                                0.3749333],
#                                                                        'label': 'O2-',
#                                                                        'properties': {'magmom': 0.217},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
#                                                                        'xyz': [1.3356637998236085,
#                                                                                8.045722454866924,
#                                                                                -1.3195115847948342]},
#                                                                       {'abc': [0.67708932,
#                                                                                0.09381543,
#                                                                                0.96876718],
#                                                                        'label': 'O2-',
#                                                                        'properties': {'magmom': 0.216},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
#                                                                        'xyz': [6.462378334280361,
#                                                                                0.832026689496232,
#                                                                                7.742778042953766]},
#                                                                       {'abc': [0.12517045,
#                                                                                0.03108579,
#                                                                                0.20818822],
#                                                                        'label': 'O2-',
#                                                                        'properties'
# /Users/mcdermott/miniconda3/envs/dev/lib/python3.7/site-packages/pymatgen/alchemy/materials.py:346: UserWarning: Data in TransformedStructure.other_parameters discarded during type conversion to SNL
#   warn('Data in TransformedStructure.other_parameters discarded '
# : {'magmom': 0.216},
#                                                                        'species': [{'element': 'O',
#                                                                                     'occu': 1,
#                                                                                     'oxidation_state': -2}],
# ...
#             'xyz': [2.5635044682521935, 2.2218795726794, 4.5332722213553245]},
#            {'abc': [0.0, 0.0, 0.5],
#             'label': 'Mn3+',
#             'properties': {'magmom': 4.404},
#             'species': [{'element': 'Mn', 'occu': 1.0, 'oxidation_state': 3}],
#             'xyz': [-0.000220885, -0.0003825, 5.438544975]},
#            {'abc': [0.12499823, 0.74996454, 0.87497119],
#             'label': 'Mn3+',
#             'properties': {'magmom': 4.276},
#             'species': [{'element': 'Mn', 'occu': 1.0, 'oxidation_state': 3}],
#             'xyz': [-2.5628814018441988,
#                     6.6605566649652825,
#                     6.345332227684734]},
#            {'abc': [0.74976366, 0.37482497, 0.62492209],
#             'label': 'Mn3+',
#             'properties': {'magmom': 4.276},
#             'species': [{'element': 'Mn', 'occu': 1.0, 'oxidation_state': 3}],
#             'xyz': [5.767344292510888, 3.3282120533012187, 2.7206124891819217]},
#            {'abc': [0.5, 0.5, 0.5],
#             'label': 'Mn3+',
#             'properties': {'magmom': 4.404},
#             'species': [{'element': 'Mn', 'occu': 1.0, 'oxidation_state': 3}],
#             'xyz': [2.56435595, 4.44032609, 1.813467165]},
#            {'abc': [0.5, 0.5, 0.0],
#             'label': 'Mn3+',
#             'properties': {'magmom': 4.404},
#             'species': [{'element': 'Mn', 'occu': 1.0, 'oxidation_state': 3}],
#             'xyz': [2.564576835, 4.44070859, -3.62507781]},
#            {'abc': [0.6250667, 0.41692244, 0.09409026],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [4.272986617448189, 3.7026309223429323, -2.753863492398982]},
#            {'abc': [0.4685611, 0.59368791, 0.17689958],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [1.7618331592554293,
#                     5.272750391006903,
#                     -1.9265826685657113]},
#            {'abc': [0.90618457, 0.03123282, 0.32291068],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [9.132893698343812,
#                     0.2764753831164851,
#                     0.11411751547951532]},
#            {'abc': [0.59368791, 0.17689958, 0.4685611],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [5.181401645178084, 1.5704416974722508, 2.3031416127725817]},
#            {'abc': [0.53106465, 0.62522516, 0.70812995],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [2.240924655054157, 5.552415786062624, 3.510752632162097]},
#            {'abc': [0.08322579, 0.87491292, 0.40617864],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-3.631556546842574, 7.770761513102459, 0.9447142423593848]},
#            {'abc': [0.96891421, 0.79181178, 0.87482955],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [5.8771653903722205,
#                     7.0316060271088014,
#                     3.1328309868866917]},
#            {'abc': [0.91677421, 0.12508708, 0.59382136],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [8.760268446842575, 1.1098906668975408, 2.682220087640614]},
#            {'abc': [0.58307756, 0.90590974, 0.3749333],
#             'label': 'O2-',
#             'properties': {'magmom': 0.217},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [1.3356637998236085,
#                     8.045722454866924,
#                     -1.3195115847948342]},
#            {'abc': [0.67708932, 0.09381543, 0.96876718],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [6.462378334280361, 0.832026689496232, 7.742778042953766]},
#            {'abc': [0.12517045, 0.03108579, 0.20818822],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [1.1242124011207866,
#                     0.27585463531090515,
#                     1.6980409652906616]},
#            {'abc': [0.96876718, 0.67708932, 0.09381543],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [6.464079593550416, 6.013217831259561, -4.9459190116198934]},
#            {'abc': [0.90590974, 0.3749333, 0.58307756],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [7.368122679499721, 3.329086827212916, 1.6990313749300512]},
#            {'abc': [0.67711671, 0.0833621, 0.70824989],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [6.516358964872089, 0.7393775833461086, 4.946902889626308]},
#            {'abc': [0.09409026, 0.6250667, 0.41692244],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-2.2394107794997216, 5.551565352787084, 1.927902955069949]},
#            {'abc': [0.82310042, 0.5314389, 0.40631209],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [5.716710585032294,
#                     4.719396641351729,
#                     -0.49081728683522385]},
#            {'abc': [0.82294349, 0.79184658, 0.41674942],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [4.380224896985318, 7.03237721864864, -1.320718723236956]},
#            {'abc': [0.70824989, 0.67711671, 0.0833621],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [3.7922770012140856, 6.013668393726536, -4.115324660876915]},
#            {'abc': [0.62522516, 0.70812995, 0.53106465],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [2.7816643723170613, 6.288854657164403, 0.9429219468622545]},
#            {'abc': [0.32288329, 0.9166379, 0.29175011],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-1.3876470648720896,
#                     8.141274596653892,
#                     -1.3199685596263078]},
#            {'abc': [0.09381543, 0.96876718, 0.67708932],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-4.004181798343811, 8.604176796883516, 3.5128168145204843]},
#            {'abc': [0.12508708, 0.59382136, 0.91677421],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-1.761585586158315, 5.2736324545718, 7.36573652211916]},
#            {'abc': [0.87491292, 0.40617864, 0.08322579],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [6.890297486158315,
#                     3.6070197254281995,
#                     -3.7388021921191585]},
#            {'abc': [0.40631209, 0.82310042, 0.5314389],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-0.05268974517808481,
#                     7.31021048252775,
#                     1.3237927172274189]},
#            {'abc': [0.87482955, 0.96891421, 0.79181178],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [4.004499498879212, 8.604797544689095, 1.9288933647093387]},
#            {'abc': [0.29187005, 0.46893535, 0.37477484],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [0.5892291176640735, 4.164659217147948, 1.3184808759499904]},
#            {'abc': [0.29175011, 0.32288329, 0.9166379],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [1.3364348987859151, 2.8669837862734635, 7.742258990876915]},
#            {'abc': [0.79181178, 0.87482955, 0.96891421],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [3.6353401718574907, 7.76904848001418, 4.497262515051657]},
#            {'abc': [0.17705651, 0.20815342, 0.58325058],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [0.748487003014683, 1.8482749613513603, 4.947653053236955]},
#            {'abc': [0.03123282, 0.32291068, 0.90618457],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-1.3353676935504162,
#                     2.8674343487404395,
#                     8.572853341619894]},
#            {'abc': [0.58325058, 0.17705651, 0.20815342],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [5.073674946042316,
#                     1.5720427742246954,
#                     -0.4920688961284245]},
#            {'abc': [0.32291068, 0.90618457, 0.03123282],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-1.3336664342803615,
#                     8.048625490503769,
#                     -4.115843712953765]},
#            {'abc': [0.5314389, 0.40631209, 0.82310042],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [3.366878740744571, 3.607901788993097, 5.55351699856571]},
#            {'abc': [0.37477484, 0.29187005, 0.46893535],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [2.347047527682938, 2.5917975228355985, 2.684012383137746]},
#            {'abc': [0.03108579, 0.20818822, 0.12517045],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-0.7484534903722206,
#                     1.8490461528911981,
#                     0.4941033431133077]},
#            {'abc': [0.20818822, 0.12517045, 0.03108579],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [1.4933717281425083,
#                     1.1116036999858194,
#                     -0.8703281850516577]},
#            {'abc': [0.41692244, 0.09409026, 0.6250667],
#             'label': 'O2-',
#             'properties': {'magmom': 0.217},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [3.793048100176392, 0.8349297251330757, 4.946445914794834]},
#            {'abc': [0.79184658, 0.41674942, 0.82294349],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [5.983918906739932, 3.700408976200644, 4.569975816140222]},
#            {'abc': [0.20815342, 0.58325058, 0.17705651],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-0.8552070067399308,
#                     5.180243203799356,
#                     -0.9430414861402223]},
#            {'abc': [0.17689958, 0.4685611, 0.59368791],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-0.5879986850322936, 4.161255538648273, 4.117751616835224]},
#            {'abc': [0.46893535, 0.37477484, 0.29187005],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [2.8877872449458435,
#                     3.328236393937377,
#                     0.11618169783790355]},
#            {'abc': [0.40617864, 0.08322579, 0.87491292],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [3.738449689005724, 0.7382466099586648, 7.742377383489398]},
#            {'abc': [0.3749333, 0.58307756, 0.90590974],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [0.8557252825518108, 5.178021257657068, 6.380797822398981]},
#            {'abc': [0.9166379, 0.29175011, 0.32288329],
#             'label': 'O2-',
#             'properties': {'magmom': 0.217},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [7.904661504524645,
#                     2.5904294255890794,
#                     -0.8684699847368789]},
#            {'abc': [0.41674942, 0.82294349, 0.79184658],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [0.05503695395768298, 7.308609405775305, 4.119003226128424]},
#            {'abc': [0.0833621, 0.70824989, 0.67711671],
#             'label': 'O2-',
#             'properties': {'magmom': 0.217},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [-2.775949604524645, 6.290222754410921, 4.495404314736877]},
#            {'abc': [0.70812995, 0.53106465, 0.62522516],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [4.539482782335926, 4.715992962852052, 2.3084534540500092]},
#            {'abc': [0.59382136, 0.91677421, 0.12508708],
#             'label': 'O2-',
#             'properties': {'magmom': 0.216},
#             'species': [{'element': 'O', 'occu': 1, 'oxidation_state': -2}],
#             'xyz': [1.3902622109942757,
#                     8.142405570041335,
#                     -4.115443053489399]}]}
